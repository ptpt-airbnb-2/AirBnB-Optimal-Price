# %% [markdown]
# ## AirBnB Optimal Price Predictor
#
# This notebook downloads the data from remote used in this project and then cleans it. Ready to be used to build a model for predictions.

# %%
# Imports
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import glob
import os
import httplib2
from bs4 import BeautifulSoup, SoupStrainer
from pandas_profiling import ProfileReport

# %%
# First Trying to get all the data from a remote site
http = httplib2.Http()
status, response = http.request('http://insideairbnb.com/get-the-data.html')

url_list = []
# loop through the response and get all the links
for link in BeautifulSoup(response, parse_only=SoupStrainer('a')):
    if link.has_attr('href'):
        # Add to the list
        url_list.append(link['href'])

# Show list
# Uncomment to see
# url_list

# %%
df = pd.DataFrame(url_list, columns=['URL'])
df
# Out:
#                                                     URL
# 0                                            index.html
# 1                                            about.html
# 2                                           behind.html
# 3                                     get-the-data.html
# 4                             https://twitter.com/share
# ...                                                 ...
# 7683  http://data.insideairbnb.com/switzerland/z%C3%...
# 7684  http://data.insideairbnb.com/switzerland/z%C3%...
# 7685  http://data.insideairbnb.com/switzerland/z%C3%...
# 7686  http://data.insideairbnb.com/switzerland/z%C3%...
# 7687  http://creativecommons.org/publicdomain/zero/1.0/
#
# [7688 rows x 1 columns]

# %%
# only filter rows that ends with 'listings.csv' and save to new df
df_listings = df[df.URL.str.endswith('listings.csv', na=False)]
df_listings.reset_index(inplace=True)
df_listings
# Out:
#       index                                                URL
# 0        14  http://data.insideairbnb.com/the-netherlands/n...
# 1        21  http://data.insideairbnb.com/the-netherlands/n...
# 2        28  http://data.insideairbnb.com/the-netherlands/n...
# 3        35  http://data.insideairbnb.com/the-netherlands/n...
# 4        42  http://data.insideairbnb.com/the-netherlands/n...
# ...     ...                                                ...
# 1076   7655  http://data.insideairbnb.com/switzerland/z%C3%...
# 1077   7662  http://data.insideairbnb.com/switzerland/z%C3%...
# 1078   7669  http://data.insideairbnb.com/switzerland/z%C3%...
# 1079   7676  http://data.insideairbnb.com/switzerland/z%C3%...
# 1080   7683  http://data.insideairbnb.com/switzerland/z%C3%...
#
# [1081 rows x 2 columns]

# %%
# build a dataframe with rightly described country, area, city and date of latest data available online
df_listings['country'] = df_listings['URL'].apply(lambda x: x.split('/')[3])
df_listings['area'] = df_listings['URL'].apply(lambda x: x.split('/')[4])
df_listings['city'] = df_listings['URL'].apply(lambda x: x.split('/')[5])
df_listings['date_of_latest_data'] = df_listings['URL'].apply(lambda x: x.split('/')[6])
df_listings
# Out:
# /Users/rob/opt/anaconda3/envs/U4-S1-NLP/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/rob/opt/anaconda3/envs/U4-S1-NLP/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/rob/opt/anaconda3/envs/U4-S1-NLP/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /Users/rob/opt/anaconda3/envs/U4-S1-NLP/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
#       index                                                URL  \
# 0        14  http://data.insideairbnb.com/the-netherlands/n...
# 1        21  http://data.insideairbnb.com/the-netherlands/n...
# 2        28  http://data.insideairbnb.com/the-netherlands/n...
# 3        35  http://data.insideairbnb.com/the-netherlands/n...
# 4        42  http://data.insideairbnb.com/the-netherlands/n...
# ...     ...                                                ...
# 1076   7655  http://data.insideairbnb.com/switzerland/z%C3%...
# 1077   7662  http://data.insideairbnb.com/switzerland/z%C3%...
# 1078   7669  http://data.insideairbnb.com/switzerland/z%C3%...
# 1079   7676  http://data.insideairbnb.com/switzerland/z%C3%...
# 1080   7683  http://data.insideairbnb.com/switzerland/z%C3%...
#
#               country           area       city date_of_latest_data
# 0     the-netherlands  north-holland  amsterdam          2021-04-09
# 1     the-netherlands  north-holland  amsterdam          2021-03-04
# 2     the-netherlands  north-holland  amsterdam          2021-02-08
# 3     the-netherlands  north-holland  amsterdam          2021-01-09
# 4     the-netherlands  north-holland  amsterdam          2020-12-12
# ...               ...            ...        ...                 ...
# 1076      switzerland    z%C3%BCrich     zurich          2020-11-29
# 1077      switzerland    z%C3%BCrich     zurich          2020-10-29
# 1078      switzerland    z%C3%BCrich     zurich          2020-06-25
# 1079      switzerland    z%C3%BCrich     zurich          2020-05-30
# 1080      switzerland    z%C3%BCrich     zurich          2020-04-30
#
# [1081 rows x 6 columns]

# %%
# Export data to a text file

np.savetxt(r'URL_List_Listings_CSV.txt', df_listings.URL, fmt="%s")

# %%
# Run a loop to download all the data in the raw directory below
# ├── data
# │   └── raw            <- The original, immutable data dump.

# Uncomment to execute. Downloads 1.75 GB data from remote
# for i in range(len(df_listings['URL'])):
#     # Loop through each loop
#     url = df_listings['URL'][i]
#     print('Downloading File ', i)
#     print(url, '\n')
#
#     # Get file name for better description of file
#     file_name = df_listings['country'][i]+'_'+df_listings['city'][i]+'_'+df_listings['date_of_latest_data'][i]+'.csv'
#
#     # Get the file
#     file = requests.get(url)
#
#     # Open to write, which saves the file instead
#     open('../data/raw/'+file_name, 'wb').write(file.content)

# %%
print(os.getcwd())
# Out:
# /Users/rob/G_Drive_sing.parvi/Colab_Notebooks/DS-Unit-4-BW/ptpt-airbnb-2/notebooks

# %%
# Change the directory to raw data
os.chdir(os.path.dirname('../data/raw/'))
print(os.getcwd())
# Out:
# /Users/rob/G_Drive_sing.parvi/Colab_Notebooks/DS-Unit-4-BW/ptpt-airbnb-2/data/raw

# %%
# create a list of all csv files
globbed_files = glob.glob('*.csv')

data = []
for csv in globbed_files:
    frame = pd.read_csv(csv)
    frame['filename'] = os.path.basename(csv)
    data.append(frame)
    print(csv," ", 'import complete.')

# Save the data list as a DataFrame
merged_df = pd.concat(data, ignore_index=True)

# Display shape
merged_df
# Out:
# portugal_porto_2020-10-21.csv   import complete.
# united-states_salem-or_2020-12-23.csv   import complete.
# switzerland_vaud_2020-06-21.csv   import complete.
# italy_rome_2020-09-13.csv   import complete.
# united-states_jersey-city_2021-03-18.csv   import complete.
# canada_new-brunswick_2020-06-25.csv   import complete.
# singapore_singapore_2020-05-27.csv   import complete.
# singapore_singapore_2021-03-25.csv   import complete.
# canada_quebec-city_2021-03-04.csv   import complete.
# united-states_san-francisco_2021-02-04.csv   import complete.
# united-states_clark-county-nv_2020-05-26.csv   import complete.
# italy_bologna_2021-04-20.csv   import complete.
# united-kingdom_greater-manchester_2020-10-25.csv   import complete.
# canada_quebec-city_2020-07-17.csv   import complete.
# portugal_porto_2020-05-28.csv   import complete.
# greece_thessaloniki_2020-10-25.csv   import complete.
# mexico_mexico-city_2020-06-20.csv   import complete.
# spain_menorca_2021-03-30.csv   import complete.
# united-states_hawaii_2021-04-14.csv   import complete.
# spain_mallorca_2020-08-28.csv   import complete.
# united-states_portland_2020-06-09.csv   import complete.
# the-netherlands_amsterdam_2020-12-12.csv   import complete.
# canada_toronto_2020-05-07.csv   import complete.
# ireland_dublin_2021-02-10.csv   import complete.
# brazil_rio-de-janeiro_2020-12-23.csv   import complete.
# south-africa_cape-town_2021-02-23.csv   import complete.
# united-kingdom_edinburgh_2020-09-19.csv   import complete.
# united-states_columbus_2020-12-29.csv   import complete.
# australia_sydney_2021-04-10.csv   import complete.
# canada_victoria_2020-10-27.csv   import complete.
# france_bordeaux_2021-04-18.csv   import complete.
# latvia_riga_2020-11-30.csv   import complete.
# australia_barwon-south-west-vic_2020-05-26.csv   import complete.
# united-states_los-angeles_2020-11-03.csv   import complete.
# japan_tokyo_2020-05-30.csv   import complete.
# australia_western-australia_2021-03-19.csv   import complete.
# china_shanghai_2020-05-24.csv   import complete.
# australia_barwon-south-west-vic_2021-03-25.csv   import complete.
# japan_tokyo_2021-03-27.csv   import complete.
# united-states_portland_2020-11-10.csv   import complete.
# united-kingdom_london_2020-10-13.csv   import complete.
# spain_mallorca_2020-11-08.csv   import complete.
# czech-republic_prague_2020-05-30.csv   import complete.
# belize_belize_2021-03-27.csv   import complete.
# portugal_porto_2020-12-19.csv   import complete.
# portugal_lisbon_2020-06-23.csv   import complete.
# belgium_brussels_2020-05-17.csv   import complete.
# united-states_pacific-grove_2021-01-30.csv   import complete.
# japan_tokyo_2020-12-29.csv   import complete.
# france_lyon_2020-07-25.csv   import complete.
# united-states_broward-county_2021-01-27.csv   import complete.
# united-states_clark-county-nv_2021-01-20.csv   import complete.
# australia_northern-rivers_2020-06-27.csv   import complete.
# united-states_nashville_2020-09-28.csv   import complete.
# italy_bologna_2020-05-16.csv   import complete.
# denmark_copenhagen_2021-02-25.csv   import complete.
# united-states_chicago_2020-08-30.csv   import complete.
# switzerland_geneva_2021-01-30.csv   import complete.
# united-states_santa-clara-county_2020-11-13.csv   import complete.
# united-states_boston_2020-06-10.csv   import complete.
# united-kingdom_london_2021-04-11.csv   import complete.
# italy_bergamo_2020-12-31.csv   import complete.
# united-states_denver_2021-01-31.csv   import complete.
# italy_venice_2020-12-12.csv   import complete.
# united-kingdom_london_2020-12-16.csv   import complete.
# australia_barossa-valley_2021-02-25.csv   import complete.
# united-states_santa-cruz-county_2020-06-30.csv   import complete.
# south-africa_gauteng_2021-01-31.csv   import complete.
# germany_munich_2020-06-20.csv   import complete.
# brazil_rio-de-janeiro_2020-10-25.csv   import complete.
# greece_crete_2020-05-28.csv   import complete.
# italy_puglia_2020-11-28.csv   import complete.
# united-states_new-orleans_2020-11-03.csv   import complete.
# the-netherlands_amsterdam_2020-09-09.csv   import complete.
# australia_sydney_2020-10-11.csv   import complete.
# greece_thessaloniki_2020-12-23.csv   import complete.
# taiwan_taipei_2020-06-29.csv   import complete.
# spain_malaga_2020-11-30.csv   import complete.
# united-kingdom_greater-manchester_2020-12-23.csv   import complete.
# belgium_ghent_2020-04-27.csv   import complete.
# greece_crete_2020-12-30.csv   import complete.
# united-states_broward-county_2021-03-20.csv   import complete.
# italy_bergamo_2021-03-29.csv   import complete.
# canada_ottawa_2020-06-30.csv   import complete.
# united-states_denver_2020-10-29.csv   import complete.
# germany_berlin_2020-08-30.csv   import complete.
# australia_sydney_2020-12-14.csv   import complete.
# norway_oslo_2021-02-26.csv   import complete.
# united-states_salem-or_2020-07-15.csv   import complete.
# canada_quebec-city_2020-09-11.csv   import complete.
# spain_menorca_2020-05-31.csv   import complete.
# norway_oslo_2020-04-30.csv   import complete.
# italy_venice_2020-09-08.csv   import complete.
# united-states_new-orleans_2021-02-08.csv   import complete.
# united-states_austin_2020-07-19.csv   import complete.
# australia_tasmania_2020-06-09.csv   import complete.
# united-states_salem-or_2020-10-25.csv   import complete.
# united-states_new-york-city_2020-08-15.csv   import complete.
# belgium_brussels_2021-03-17.csv   import complete.
# italy_sicily_2020-10-27.csv   import complete.
# italy_naples_2021-02-17.csv   import complete.
# argentina_buenos-aires_2020-06-21.csv   import complete.
# spain_euskadi_2020-10-30.csv   import complete.
# sweden_stockholm_2020-10-27.csv   import complete.
# the-netherlands_amsterdam_2020-05-08.csv   import complete.
# france_bordeaux_2021-03-07.csv   import complete.
# italy_rome_2021-03-07.csv   import complete.
# australia_visualisations_listings.csv.csv   import complete.
# united-states_jersey-city_2021-01-23.csv   import complete.
# united-states_los-angeles_2020-08-20.csv   import complete.
# china_beijing_2020-12-23.csv   import complete.
# italy_trentino_2021-01-31.csv   import complete.
# italy_naples_2020-11-09.csv   import complete.
# china_beijing_2020-10-26.csv   import complete.
# united-states_broward-county_2020-05-23.csv   import complete.
# spain_madrid_2020-06-13.csv   import complete.
# italy_puglia_2020-06-25.csv   import complete.
# singapore_singapore_2020-12-29.csv   import complete.
# united-states_austin_2021-04-16.csv   import complete.
# france_bordeaux_2020-10-24.csv   import complete.
# canada_toronto_2021-01-02.csv   import complete.
# canada_montreal_2020-11-07.csv   import complete.
# canada_quebec-city_2020-05-10.csv   import complete.
# united-states_cambridge_2020-04-28.csv   import complete.
# canada_vancouver_2021-02-09.csv   import complete.
# united-kingdom_bristol_2020-12-29.csv   import complete.
# france_bordeaux_2021-01-16.csv   import complete.
# germany_berlin_2020-11-10.csv   import complete.
# united-states_seattle_2020-11-12.csv   import complete.
# united-states_jersey-city_2020-05-30.csv   import complete.
# turkey_istanbul_2020-06-28.csv   import complete.
# united-kingdom_edinburgh_2020-05-27.csv   import complete.
# czech-republic_prague_2021-01-20.csv   import complete.
# thailand_bangkok_2020-04-27.csv   import complete.
# taiwan_taipei_2020-11-30.csv   import complete.
# italy_bologna_2020-10-24.csv   import complete.
# united-kingdom_greater-manchester_2020-05-16.csv   import complete.
# canada_victoria_2020-12-30.csv   import complete.
# united-states_washington-dc_2020-12-20.csv   import complete.
# argentina_buenos-aires_2021-02-23.csv   import complete.
# the-netherlands_amsterdam_2020-07-09.csv   import complete.
# belgium_brussels_2020-10-25.csv   import complete.
# spain_sevilla_2021-03-29.csv   import complete.
# italy_trentino_2021-03-30.csv   import complete.
# spain_barcelona_2020-10-12.csv   import complete.
# united-states_portland_2021-02-20.csv   import complete.
# united-states_columbus_2020-05-23.csv   import complete.
# united-states_seattle_2021-02-21.csv   import complete.
# united-states_san-diego_2020-06-17.csv   import complete.
# france_bordeaux_2020-12-19.csv   import complete.
# greece_south-aegean_2020-04-28.csv   import complete.
# italy_puglia_2020-04-30.csv   import complete.
# canada_toronto_2021-03-03.csv   import complete.
# switzerland_geneva_2021-03-26.csv   import complete.
# canada_ottawa_2020-04-30.csv   import complete.
# united-states_denver_2020-12-29.csv   import complete.
# canada_vancouver_2020-11-06.csv   import complete.
# italy_bologna_2020-12-21.csv   import complete.
# australia_barossa-valley_2020-06-19.csv   import complete.
# australia_sydney_2020-05-09.csv   import complete.
# italy_rome_2020-05-15.csv   import complete.
# united-states_denver_2020-05-30.csv   import complete.
# switzerland_geneva_2020-12-29.csv   import complete.
# singapore_singapore_2021-01-27.csv   import complete.
# united-states_twin-cities-msa_2020-07-09.csv   import complete.
# turkey_istanbul_2020-04-28.csv   import complete.
# united-states_washington-dc_2020-10-24.csv   import complete.
# germany_munich_2021-02-23.csv   import complete.
# united-kingdom_bristol_2021-01-27.csv   import complete.
# united-states_san-francisco_2020-08-15.csv   import complete.
# spain_barcelona_2020-12-16.csv   import complete.
# italy_milan_2020-09-24.csv   import complete.
# united-states_columbus_2021-03-20.csv   import complete.
# italy_bologna_2021-03-12.csv   import complete.
# united-states_washington-dc_2021-01-16.csv   import complete.
# united-states_pacific-grove_2020-05-31.csv   import complete.
# chile_santiago_2020-05-25.csv   import complete.
# canada_ottawa_2020-08-25.csv   import complete.
# united-states_rhode-island_2020-12-30.csv   import complete.
# switzerland_vaud_2020-11-02.csv   import complete.
# spain_mallorca_2021-02-11.csv   import complete.
# canada_victoria_2020-05-29.csv   import complete.
# united-states_san-mateo-county_2020-07-15.csv   import complete.
# spain_valencia_2020-04-28.csv   import complete.
# united-states_pacific-grove_2020-12-29.csv   import complete.
# austria_vienna_2021-04-13.csv   import complete.
# italy_naples_2020-06-14.csv   import complete.
# canada_toronto_2020-10-09.csv   import complete.
# spain_euskadi_2020-12-31.csv   import complete.
# austria_vienna_2020-05-18.csv   import complete.
# united-states_san-mateo-county_2020-10-25.csv   import complete.
# united-kingdom_edinburgh_2021-03-08.csv   import complete.
# belize_belize_2021-01-30.csv   import complete.
# denmark_copenhagen_2020-11-28.csv   import complete.
# italy_rome_2021-01-13.csv   import complete.
# thailand_bangkok_2021-02-22.csv   import complete.
# south-africa_cape-town_2020-06-21.csv   import complete.
# australia_barwon-south-west-vic_2021-01-30.csv   import complete.
# italy_sicily_2020-12-30.csv   import complete.
# denmark_copenhagen_2020-06-26.csv   import complete.
# united-states_nashville_2021-03-12.csv   import complete.
# belgium_ghent_2021-02-23.csv   import complete.
# united-states_columbus_2021-01-27.csv   import complete.
# portugal_porto_2021-01-16.csv   import complete.
# united-states_pacific-grove_2021-03-31.csv   import complete.
# united-states_new-orleans_2020-08-18.csv   import complete.
# chile_santiago_2021-03-25.csv   import complete.
# italy_sicily_2020-05-28.csv   import complete.
# canada_toronto_2021-01-11.csv   import complete.
# united-kingdom_bristol_2021-03-20.csv   import complete.
# spain_girona_2020-06-29.csv   import complete.
# greece_athens_2020-11-17.csv   import complete.
# united-states_new-orleans_2020-06-09.csv   import complete.
# thailand_bangkok_2020-11-29.csv   import complete.
# belgium_ghent_2020-06-18.csv   import complete.
# france_paris_2020-06-11.csv   import complete.
# austria_vienna_2020-10-13.csv   import complete.
# italy_puglia_2021-02-25.csv   import complete.
# germany_berlin_2021-02-20.csv   import complete.
# greece_crete_2020-10-27.csv   import complete.
# canada_toronto_2021-04-09.csv   import complete.
# thailand_bangkok_2020-06-19.csv   import complete.
# united-states_santa-cruz-county_2021-02-27.csv   import complete.
# united-states_twin-cities-msa_2021-01-21.csv   import complete.
# australia_tasmania_2020-11-03.csv   import complete.
# italy_venice_2020-10-07.csv   import complete.
# italy_bergamo_2020-10-30.csv   import complete.
# canada_vancouver_2020-08-24.csv   import complete.
# spain_barcelona_2021-04-12.csv   import complete.
# austria_vienna_2020-07-22.csv   import complete.
# greece_athens_2021-02-21.csv   import complete.
# united-states_asheville_2020-11-08.csv   import complete.
# united-states_santa-cruz-county_2020-04-30.csv   import complete.
# south-africa_gauteng_2020-05-31.csv   import complete.
# united-states_santa-clara-county_2021-02-21.csv   import complete.
# canada_new-brunswick_2020-04-30.csv   import complete.
# united-states_nashville_2020-10-24.csv   import complete.
# australia_melbourne_2020-06-11.csv   import complete.
# italy_venice_2021-01-08.csv   import complete.
# china_hong-kong_2021-01-21.csv   import complete.
# france_lyon_2020-09-19.csv   import complete.
# belgium_brussels_2020-12-22.csv   import complete.
# canada_quebec-city_2021-01-11.csv   import complete.
# belgium_antwerp_2020-04-28.csv   import complete.
# united-kingdom_bristol_2020-05-23.csv   import complete.
# united-states_asheville_2021-02-17.csv   import complete.
# united-states_chicago_2020-06-18.csv   import complete.
# france_lyon_2020-05-25.csv   import complete.
# austria_vienna_2020-12-17.csv   import complete.
# united-states_dallas_2021-04-17.csv   import complete.
# spain_menorca_2021-01-31.csv   import complete.
# united-states_washington-dc_2021-04-19.csv   import complete.
# mexico_mexico-city_2021-02-23.csv   import complete.
# norway_oslo_2020-06-26.csv   import complete.
# japan_tokyo_2021-01-27.csv   import complete.
# china_shanghai_2021-01-26.csv   import complete.
# australia_western-australia_2021-01-24.csv   import complete.
# united-states_broward-county_2020-12-29.csv   import complete.
# the-netherlands_amsterdam_2021-01-09.csv   import complete.
# sweden_stockholm_2020-12-30.csv   import complete.
# united-states_oakland_2020-06-17.csv   import complete.
# spain_sevilla_2020-12-31.csv   import complete.
# united-states_new-york-city_2021-02-04.csv   import complete.
# united-states_nashville_2020-12-21.csv   import complete.
# belgium_ghent_2021-01-28.csv   import complete.
# united-states_washington-dc_2020-06-18.csv   import complete.
# mexico_mexico-city_2021-01-29.csv   import complete.
# united-states_chicago_2021-04-19.csv   import complete.
# greece_crete_2020-11-29.csv   import complete.
# switzerland_zurich_2021-03-27.csv   import complete.
# germany_berlin_2021-03-12.csv   import complete.
# australia_barossa-valley_2020-07-28.csv   import complete.
# italy_milan_2020-11-09.csv   import complete.
# spain_malaga_2020-05-31.csv   import complete.
# australia_northern-rivers_2020-10-21.csv   import complete.
# canada_montreal_2021-01-14.csv   import complete.
# switzerland_vaud_2020-09-07.csv   import complete.
# spain_menorca_2020-11-30.csv   import complete.
# australia_barossa-valley_2021-04-26.csv   import complete.
# france_bordeaux_2020-06-21.csv   import complete.
# united-states_rhode-island_2020-04-30.csv   import complete.
# spain_barcelona_2020-06-13.csv   import complete.
# portugal_lisbon_2020-12-20.csv   import complete.
# united-states_santa-clara-county_2020-10-25.csv   import complete.
# sweden_stockholm_2021-02-25.csv   import complete.
# united-states_pacific-grove_2020-04-29.csv   import complete.
# spain_euskadi_2021-02-27.csv   import complete.
# china_hong-kong_2020-04-29.csv   import complete.
# canada_toronto_2020-08-18.csv   import complete.
# united-states_los-angeles_2021-03-03.csv   import complete.
# australia_melbourne_2021-04-10.csv   import complete.
# china_shanghai_2020-11-27.csv   import complete.
# spain_girona_2021-01-31.csv   import complete.
# greece_athens_2020-10-25.csv   import complete.
# belgium_antwerp_2020-05-27.csv   import complete.
# italy_florence_2020-05-24.csv   import complete.
# canada_toronto_2020-06-08.csv   import complete.
# italy_sicily_2021-02-25.csv   import complete.
# united-states_new-orleans_2021-01-10.csv   import complete.
# spain_euskadi_2020-04-30.csv   import complete.
# united-states_san-francisco_2021-04-07.csv   import complete.
# italy_venice_2020-04-29.csv   import complete.
# united-states_boston_2021-01-19.csv   import complete.
# canada_victoria_2020-04-30.csv   import complete.
# italy_milan_2020-04-29.csv   import complete.
# france_paris_2021-04-10.csv   import complete.
# italy_milan_2021-02-17.csv   import complete.
# canada_victoria_2021-02-26.csv   import complete.
# thailand_bangkok_2020-12-23.csv   import complete.
# spain_mallorca_2021-03-08.csv   import complete.
# united-states_new-york-city_2020-12-10.csv   import complete.
# united-states_portland_2020-12-22.csv   import complete.
# united-states_rhode-island_2021-02-27.csv   import complete.
# canada_ottawa_2020-10-21.csv   import complete.
# spain_valencia_2020-05-31.csv   import complete.
# spain_madrid_2020-10-17.csv   import complete.
# united-kingdom_edinburgh_2021-02-11.csv   import complete.
# mexico_mexico-city_2020-12-23.csv   import complete.
# germany_berlin_2020-12-21.csv   import complete.
# united-states_los-angeles_2020-10-09.csv   import complete.
# united-states_san-francisco_2020-10-05.csv   import complete.
# italy_puglia_2020-12-30.csv   import complete.
# portugal_lisbon_2021-01-16.csv   import complete.
# france_paris_2020-10-12.csv   import complete.
# turkey_istanbul_2020-05-19.csv   import complete.
# united-states_seattle_2020-12-23.csv   import complete.
# mexico_mexico-city_2020-10-26.csv   import complete.
# switzerland_geneva_2020-04-28.csv   import complete.
# switzerland_zurich_2020-05-30.csv   import complete.
# greece_south-aegean_2020-05-30.csv   import complete.
# italy_florence_2020-09-25.csv   import complete.
# united-states_san-diego_2020-07-27.csv   import complete.
# united-kingdom_greater-manchester_2020-11-13.csv   import complete.
# taiwan_taipei_2020-05-31.csv   import complete.
# united-states_santa-clara-county_2020-12-23.csv   import complete.
# united-states_san-mateo-county_2021-02-21.csv   import complete.
# canada_new-brunswick_2020-12-30.csv   import complete.
# greece_athens_2020-12-23.csv   import complete.
# italy_venice_2020-06-12.csv   import complete.
# argentina_buenos-aires_2020-10-26.csv   import complete.
# italy_puglia_2021-03-28.csv   import complete.
# belgium_brussels_2021-02-20.csv   import complete.
# spain_malaga_2021-03-30.csv   import complete.
# belgium_ghent_2020-10-25.csv   import complete.
# australia_melbourne_2020-10-11.csv   import complete.
# united-kingdom_bristol_2020-11-26.csv   import complete.
# canada_vancouver_2021-01-12.csv   import complete.
# denmark_copenhagen_2020-10-27.csv   import complete.
# czech-republic_prague_2020-06-28.csv   import complete.
# australia_melbourne_2020-12-14.csv   import complete.
# united-states_chicago_2020-10-24.csv   import complete.
# spain_girona_2020-10-28.csv   import complete.
# italy_naples_2021-01-19.csv   import complete.
# italy_rome_2020-11-06.csv   import complete.
# canada_montreal_2020-10-19.csv   import complete.
# spain_sevilla_2021-02-27.csv   import complete.
# belgium_antwerp_2021-03-26.csv   import complete.
# latvia_riga_2020-05-31.csv   import complete.
# united-states_chicago_2021-01-16.csv   import complete.
# australia_tasmania_2020-05-07.csv   import complete.
# united-states_portland_2021-03-13.csv   import complete.
# greece_south-aegean_2021-01-20.csv   import complete.
# italy_sicily_2020-04-30.csv   import complete.
# united-states_portland_2020-05-11.csv   import complete.
# united-states_san-diego_2020-05-21.csv   import complete.
# germany_munich_2020-10-26.csv   import complete.
# spain_sevilla_2020-04-30.csv   import complete.
# belgium_antwerp_2020-12-29.csv   import complete.
# united-states_new-orleans_2020-10-09.csv   import complete.
# germany_munich_2021-01-28.csv   import complete.
# norway_oslo_2020-10-27.csv   import complete.
# italy_rome_2020-08-26.csv   import complete.
# united-states_seattle_2020-10-25.csv   import complete.
# france_paris_2020-12-14.csv   import complete.
# united-states_portland_2020-10-24.csv   import complete.
# ireland_dublin_2020-12-17.csv   import complete.
# united-states_chicago_2020-12-20.csv   import complete.
# argentina_buenos-aires_2021-01-29.csv   import complete.
# australia_barossa-valley_2021-01-28.csv   import complete.
# united-states_salem-or_2020-11-13.csv   import complete.
# canada_new-brunswick_2020-05-29.csv   import complete.
# canada_montreal_2021-03-07.csv   import complete.
# canada_quebec-city_2020-11-06.csv   import complete.
# united-states_san-francisco_2021-01-08.csv   import complete.
# united-states_austin_2020-06-13.csv   import complete.
# ireland_dublin_2020-05-27.csv   import complete.
# italy_florence_2020-07-23.csv   import complete.
# singapore_singapore_2020-11-27.csv   import complete.
# united-states_asheville_2020-09-24.csv   import complete.
# taiwan_taipei_2021-03-30.csv   import complete.
# belgium_ghent_2020-07-28.csv   import complete.
# united-states_cambridge_2021-01-30.csv   import complete.
# south-africa_cape-town_2020-12-24.csv   import complete.
# thailand_bangkok_2020-10-25.csv   import complete.
# united-states_santa-cruz-county_2020-12-31.csv   import complete.
# australia_barossa-valley_2020-10-26.csv   import complete.
# united-states_hawaii_2021-02-10.csv   import complete.
# canada_quebec-city_2020-08-23.csv   import complete.
# united-states_nashville_2020-08-30.csv   import complete.
# spain_mallorca_2020-09-19.csv   import complete.
# ireland_dublin_2021-04-14.csv   import complete.
# italy_florence_2021-01-19.csv   import complete.
# canada_toronto_2021-02-08.csv   import complete.
# italy_sicily_2020-06-25.csv   import complete.
# switzerland_vaud_2021-03-03.csv   import complete.
# united-states_new-york-city_2021-01-08.csv   import complete.
# united-states_oakland_2021-03-31.csv   import complete.
# united-kingdom_edinburgh_2020-08-28.csv   import complete.
# greece_crete_2020-06-23.csv   import complete.
# latvia_riga_2020-10-29.csv   import complete.
# italy_sicily_2020-11-29.csv   import complete.
# china_beijing_2021-02-22.csv   import complete.
# spain_valencia_2021-01-19.csv   import complete.
# canada_toronto_2020-11-03.csv   import complete.
# austria_vienna_2021-02-10.csv   import complete.
# china_beijing_2020-06-19.csv   import complete.
# united-states_cambridge_2021-03-25.csv   import complete.
# canada_quebec-city_2021-02-09.csv   import complete.
# united-states_santa-cruz-county_2020-10-30.csv   import complete.
# italy_bergamo_2021-02-27.csv   import complete.
# switzerland_zurich_2021-01-30.csv   import complete.
# united-states_austin_2021-02-10.csv   import complete.
# australia_tasmania_2021-04-08.csv   import complete.
# united-states_cambridge_2020-05-26.csv   import complete.
# taiwan_taipei_2021-01-30.csv   import complete.
# south-africa_gauteng_2020-11-30.csv   import complete.
# united-states_salem-or_2021-02-21.csv   import complete.
# canada_vancouver_2020-05-11.csv   import complete.
# switzerland_geneva_2020-11-27.csv   import complete.
# turkey_istanbul_2021-01-30.csv   import complete.
# united-states_san-mateo-county_2020-11-12.csv   import complete.
# belgium_ghent_2020-12-30.csv   import complete.
# spain_malaga_2021-01-31.csv   import complete.
# greece_athens_2020-05-17.csv   import complete.
# austria_vienna_2020-06-16.csv   import complete.
# chile_santiago_2020-11-27.csv   import complete.
# sweden_stockholm_2020-11-29.csv   import complete.
# japan_tokyo_2020-04-28.csv   import complete.
# united-states_nashville_2020-11-10.csv   import complete.
# czech-republic_prague_2020-04-29.csv   import complete.
# canada_ottawa_2021-04-19.csv   import complete.
# belgium_antwerp_2021-01-27.csv   import complete.
# united-states_pacific-grove_2020-08-12.csv   import complete.
# spain_madrid_2021-04-13.csv   import complete.
# united-states_san-diego_2021-01-23.csv   import complete.
# united-kingdom_edinburgh_2020-11-08.csv   import complete.
# canada_montreal_2020-12-18.csv   import complete.
# italy_bologna_2021-02-19.csv   import complete.
# canada_victoria_2020-06-25.csv   import complete.
# greece_thessaloniki_2020-11-17.csv   import complete.
# germany_munich_2020-12-24.csv   import complete.
# united-states_washington-dc_2020-08-30.csv   import complete.
# united-states_new-york-city_2020-10-05.csv   import complete.
# china_hong-kong_2020-06-15.csv   import complete.
# australia_northern-rivers_2021-01-16.csv   import complete.
# united-states_portland_2020-07-07.csv   import complete.
# denmark_copenhagen_2020-12-30.csv   import complete.
# norway_oslo_2020-12-31.csv   import complete.
# united-states_oakland_2020-05-18.csv   import complete.
# united-states_rhode-island_2020-06-30.csv   import complete.
# united-states_pacific-grove_2020-11-19.csv   import complete.
# canada_ottawa_2020-12-20.csv   import complete.
# australia_barwon-south-west-vic_2020-04-28.csv   import complete.
# united-states_new-york-city_2021-04-07.csv   import complete.
# united-states_oakland_2021-01-23.csv   import complete.
# switzerland_zurich_2020-10-29.csv   import complete.
# canada_vancouver_2021-03-05.csv   import complete.
# australia_western-australia_2020-06-10.csv   import complete.
# united-states_san-francisco_2020-12-10.csv   import complete.
# united-states_denver_2020-06-28.csv   import complete.
# south-africa_cape-town_2020-10-26.csv   import complete.
# canada_new-brunswick_2020-10-27.csv   import complete.
# united-states_nashville_2021-02-19.csv   import complete.
# italy_bologna_2020-08-31.csv   import complete.
# australia_barossa-valley_2020-12-30.csv   import complete.
# portugal_porto_2020-06-23.csv   import complete.
# france_lyon_2021-02-11.csv   import complete.
# united-states_clark-county-nv_2020-04-28.csv   import complete.
# ireland_dublin_2020-07-25.csv   import complete.
# canada_ottawa_2021-01-17.csv   import complete.
# australia_tasmania_2021-03-03.csv   import complete.
# italy_venice_2021-02-07.csv   import complete.
# united-states_denver_2020-11-30.csv   import complete.
# argentina_buenos-aires_2020-12-24.csv   import complete.
# greece_south-aegean_2020-09-21.csv   import complete.
# belgium_brussels_2020-11-10.csv   import complete.
# brazil_rio-de-janeiro_2020-06-19.csv   import complete.
# portugal_porto_2020-08-27.csv   import complete.
# australia_northern-rivers_2020-12-20.csv   import complete.
# greece_crete_2020-04-30.csv   import complete.
# italy_naples_2020-07-20.csv   import complete.
# italy_naples_2020-09-25.csv   import complete.
# greece_crete_2021-02-26.csv   import complete.
# portugal_lisbon_2020-05-28.csv   import complete.
# canada_montreal_2020-09-17.csv   import complete.
# australia_sydney_2020-06-11.csv   import complete.
# united-kingdom_greater-manchester_2021-02-21.csv   import complete.
# greece_thessaloniki_2021-02-21.csv   import complete.
# spain_madrid_2020-12-17.csv   import complete.
# canada_vancouver_2020-07-17.csv   import complete.
# canada_vancouver_2020-09-12.csv   import complete.
# canada_montreal_2020-05-17.csv   import complete.
# switzerland_vaud_2021-04-08.csv   import complete.
# united-states_los-angeles_2021-01-02.csv   import complete.
# germany_berlin_2020-05-14.csv   import complete.
# latvia_riga_2021-01-31.csv   import complete.
# united-states_new-orleans_2021-03-04.csv   import complete.
# sweden_stockholm_2020-06-26.csv   import complete.
# italy_milan_2020-06-15.csv   import complete.
# portugal_lisbon_2020-10-21.csv   import complete.
# italy_bologna_2020-04-30.csv   import complete.
# united-states_oakland_2020-12-29.csv   import complete.
# brazil_rio-de-janeiro_2021-02-22.csv   import complete.
# united-kingdom_london_2020-06-11.csv   import complete.
# norway_oslo_2020-05-28.csv   import complete.
# denmark_copenhagen_2020-05-30.csv   import complete.
# spain_menorca_2020-04-30.csv   import complete.
# norway_oslo_2021-03-27.csv   import complete.
# france_paris_2020-07-16.csv   import complete.
# united-states_rhode-island_2020-11-30.csv   import complete.
# italy_venice_2020-08-21.csv   import complete.
# united-states_clark-county-nv_2020-06-21.csv   import complete.
# spain_valencia_2020-10-24.csv   import complete.
# canada_vancouver_2020-10-16.csv   import complete.
# united-states_portland_2021-01-21.csv   import complete.
# germany_munich_2020-05-24.csv   import complete.
# italy_florence_2020-10-24.csv   import complete.
# ireland_visualisations_listings.csv.csv   import complete.
# spain_barcelona_2021-02-09.csv   import complete.
# united-kingdom_edinburgh_2020-04-27.csv   import complete.
# united-states_santa-cruz-county_2021-01-31.csv   import complete.
# united-states_jersey-city_2020-04-30.csv   import complete.
# united-states_cambridge_2020-12-30.csv   import complete.
# taiwan_taipei_2020-10-30.csv   import complete.
# italy_rome_2020-06-14.csv   import complete.
# australia_barossa-valley_2020-05-24.csv   import complete.
# south-africa_cape-town_2021-01-30.csv   import complete.
# argentina_buenos-aires_2020-05-25.csv   import complete.
# italy_florence_2020-12-21.csv   import complete.
# ireland_dublin_2020-10-19.csv   import complete.
# united-states_los-angeles_2020-05-08.csv   import complete.
# china_beijing_2020-11-26.csv   import complete.
# australia_melbourne_2021-03-04.csv   import complete.
# italy_puglia_2021-01-27.csv   import complete.
# united-states_asheville_2021-03-11.csv   import complete.
# spain_valencia_2020-12-21.csv   import complete.
# chile_santiago_2021-02-23.csv   import complete.
# australia_melbourne_2020-05-13.csv   import complete.
# united-states_asheville_2021-04-19.csv   import complete.
# canada_ottawa_2020-09-21.csv   import complete.
# italy_florence_2021-03-12.csv   import complete.
# spain_malaga_2020-10-30.csv   import complete.
# australia_sydney_2020-11-05.csv   import complete.
# new-zealand_visualisations_listings.csv.csv   import complete.
# france_paris_2021-03-04.csv   import complete.
# united-states_washington-dc_2021-02-17.csv   import complete.
# greece_south-aegean_2020-10-24.csv   import complete.
# spain_valencia_2021-03-12.csv   import complete.
# italy_puglia_2020-10-28.csv   import complete.
# greece_athens_2020-07-21.csv   import complete.
# italy_bologna_2020-11-09.csv   import complete.
# canada_new-brunswick_2021-01-30.csv   import complete.
# south-africa_gauteng_2020-06-27.csv   import complete.
# switzerland_vaud_2020-07-22.csv   import complete.
# switzerland_vaud_2021-01-08.csv   import complete.
# greece_south-aegean_2020-12-21.csv   import complete.
# united-states_broward-county_2020-11-17.csv   import complete.
# united-states_clark-county-nv_2020-11-10.csv   import complete.
# japan_tokyo_2021-02-25.csv   import complete.
# belgium_antwerp_2020-10-26.csv   import complete.
# spain_euskadi_2020-11-30.csv   import complete.
# united-states_santa-clara-county_2020-05-30.csv   import complete.
# united-states_washington-dc_2020-11-08.csv   import complete.
# greece_thessaloniki_2020-06-16.csv   import complete.
# united-kingdom_edinburgh_2020-06-23.csv   import complete.
# canada_victoria_2020-11-30.csv   import complete.
# united-states_clark-county-nv_2020-08-31.csv   import complete.
# united-states_los-angeles_2020-09-09.csv   import complete.
# united-states_pacific-grove_2020-06-30.csv   import complete.
# greece_south-aegean_2021-03-13.csv   import complete.
# ireland_dublin_2021-03-07.csv   import complete.
# australia_tasmania_2020-07-09.csv   import complete.
# spain_girona_2021-03-28.csv   import complete.
# spain_euskadi_2020-06-28.csv   import complete.
# australia_northern-rivers_2020-09-20.csv   import complete.
# denmark_copenhagen_2021-03-27.csv   import complete.
# spain_menorca_2021-02-27.csv   import complete.
# united-states_seattle_2021-03-18.csv   import complete.
# united-states_boston_2021-04-20.csv   import complete.
# united-kingdom_london_2020-08-24.csv   import complete.
# united-states_jersey-city_2020-11-12.csv   import complete.
# spain_sevilla_2020-06-29.csv   import complete.
# united-states_asheville_2021-01-17.csv   import complete.
# united-states_san-francisco_2020-09-07.csv   import complete.
# canada_ottawa_2021-03-09.csv   import complete.
# united-states_new-orleans_2020-05-08.csv   import complete.
# spain_girona_2020-05-28.csv   import complete.
# united-states_jersey-city_2020-06-22.csv   import complete.
# italy_rome_2021-02-10.csv   import complete.
# switzerland_vaud_2020-05-19.csv   import complete.
# italy_naples_2021-04-20.csv   import complete.
# china_shanghai_2020-04-30.csv   import complete.
# australia_barwon-south-west-vic_2021-02-25.csv   import complete.
# australia_tasmania_2020-10-07.csv   import complete.
# spain_mallorca_2020-12-19.csv   import complete.
# united-states_new-york-city_2021-03-01.csv   import complete.
# portugal_porto_2020-11-08.csv   import complete.
# brazil_rio-de-janeiro_2020-11-27.csv   import complete.
# united-states_twin-cities-msa_2021-02-20.csv   import complete.
# united-states_asheville_2020-12-20.csv   import complete.
# germany_berlin_2020-10-13.csv   import complete.
# australia_barwon-south-west-vic_2020-06-22.csv   import complete.
# united-states_seattle_2021-01-23.csv   import complete.
# united-states_san-diego_2021-03-17.csv   import complete.
# turkey_istanbul_2020-10-27.csv   import complete.
# france_paris_2020-05-10.csv   import complete.
# mexico_mexico-city_2020-05-24.csv   import complete.
# spain_madrid_2021-01-12.csv   import complete.
# australia_western-australia_2020-11-13.csv   import complete.
# australia_northern-rivers_2021-03-09.csv   import complete.
# the-netherlands_amsterdam_2020-11-03.csv   import complete.
# united-states_broward-county_2021-02-23.csv   import complete.
# united-states_san-francisco_2020-05-06.csv   import complete.
# china_hong-kong_2021-02-20.csv   import complete.
# italy_bergamo_2020-04-28.csv   import complete.
# united-states_new-orleans_2020-09-09.csv   import complete.
# spain_mallorca_2020-05-28.csv   import complete.
# united-states_boston_2020-07-11.csv   import complete.
# united-states_boston_2020-09-28.csv   import complete.
# switzerland_vaud_2020-10-05.csv   import complete.
# czech-republic_prague_2020-11-10.csv   import complete.
# belgium_ghent_2020-05-24.csv   import complete.
# singapore_singapore_2021-02-25.csv   import complete.
# china_shanghai_2020-06-20.csv   import complete.
# singapore_singapore_2020-06-22.csv   import complete.
# spain_girona_2020-12-31.csv   import complete.
# france_bordeaux_2021-02-11.csv   import complete.
# united-states_asheville_2020-10-24.csv   import complete.
# italy_venice_2020-11-02.csv   import complete.
# the-netherlands_amsterdam_2021-02-08.csv   import complete.
# italy_naples_2020-05-16.csv   import complete.
# united-states_santa-clara-county_2021-03-19.csv   import complete.
# belize_belize_2020-04-30.csv   import complete.
# spain_mallorca_2020-10-21.csv   import complete.
# spain_sevilla_2020-11-30.csv   import complete.
# united-states_new-york-city_2020-07-07.csv   import complete.
# united-kingdom_greater-manchester_2020-06-15.csv   import complete.
# belize_belize_2021-02-26.csv   import complete.
# united-kingdom_london_2020-11-06.csv   import complete.
# united-states_broward-county_2020-06-18.csv   import complete.
# australia_tasmania_2021-01-08.csv   import complete.
# spain_madrid_2020-05-14.csv   import complete.
# australia_melbourne_2020-09-10.csv   import complete.
# france_paris_2020-09-11.csv   import complete.
# united-states_seattle_2020-05-21.csv   import complete.
# switzerland_vaud_2020-12-10.csv   import complete.
# united-states_columbus_2021-02-23.csv   import complete.
# united-states_boston_2021-03-12.csv   import complete.
# united-states_salem-or_2020-06-12.csv   import complete.
# france_lyon_2020-08-31.csv   import complete.
# united-states_san-francisco_2020-07-07.csv   import complete.
# austria_vienna_2020-11-06.csv   import complete.
# italy_bergamo_2020-06-29.csv   import complete.
# canada_montreal_2021-04-17.csv   import complete.
# united-states_san-diego_2020-10-25.csv   import complete.
# south-africa_cape-town_2020-05-25.csv   import complete.
# thailand_bangkok_2021-01-26.csv   import complete.
# australia_western-australia_2021-02-21.csv   import complete.
# china_beijing_2020-04-29.csv   import complete.
# belize_belize_2020-06-25.csv   import complete.
# united-states_new-york-city_2020-05-06.csv   import complete.
# united-states_santa-clara-county_2021-01-24.csv   import complete.
# latvia_riga_2020-12-31.csv   import complete.
# canada_vancouver_2021-04-12.csv   import complete.
# japan_tokyo_2020-06-25.csv   import complete.
# belize_belize_2020-11-29.csv   import complete.
# united-states_columbus_2020-06-18.csv   import complete.
# norway_oslo_2021-01-30.csv   import complete.
# united-kingdom_london_2021-02-09.csv   import complete.
# united-states_clark-county-nv_2021-02-20.csv   import complete.
# germany_berlin_2020-09-23.csv   import complete.
# japan_tokyo_2020-11-29.csv   import complete.
# united-states_asheville_2020-05-29.csv   import complete.
# sweden_stockholm_2020-04-28.csv   import complete.
# switzerland_geneva_2020-06-23.csv   import complete.
# united-states_chicago_2020-09-21.csv   import complete.
# chile_santiago_2020-04-27.csv   import complete.
# germany_berlin_2021-01-19.csv   import complete.
# ireland_dublin_2020-09-17.csv   import complete.
# united-states_san-francisco_2021-03-01.csv   import complete.
# united-states_new-orleans_2020-07-09.csv   import complete.
# mexico_mexico-city_2021-03-22.csv   import complete.
# norway_oslo_2020-07-27.csv   import complete.
# italy_trentino_2021-02-27.csv   import complete.
# denmark_copenhagen_2021-01-30.csv   import complete.
# australia_tasmania_2020-12-12.csv   import complete.
# spain_valencia_2021-04-21.csv   import complete.
# spain_barcelona_2020-08-24.csv   import complete.
# australia_barossa-valley_2021-03-21.csv   import complete.
# united-states_boston_2020-10-24.csv   import complete.
# united-states_jersey-city_2021-02-21.csv   import complete.
# united-states_hawaii_2020-11-07.csv   import complete.
# portugal_lisbon_2021-03-08.csv   import complete.
# italy_bergamo_2020-11-30.csv   import complete.
# austria_vienna_2020-08-26.csv   import complete.
# united-states_austin_2020-11-07.csv   import complete.
# china_shanghai_2021-02-22.csv   import complete.
# united-states_new-orleans_2020-12-14.csv   import complete.
# greece_athens_2021-03-20.csv   import complete.
# italy_naples_2021-03-11.csv   import complete.
# australia_sydney_2021-02-08.csv   import complete.
# south-africa_gauteng_2020-04-30.csv   import complete.
# united-states_new-york-city_2020-09-07.csv   import complete.
# united-states_boston_2020-12-21.csv   import complete.
# south-africa_gauteng_2021-02-26.csv   import complete.
# united-states_cambridge_2020-10-26.csv   import complete.
# turkey_istanbul_2021-03-28.csv   import complete.
# united-states_santa-cruz-county_2020-05-31.csv   import complete.
# spain_madrid_2021-03-07.csv   import complete.
# france_lyon_2020-06-21.csv   import complete.
# switzerland_geneva_2021-02-25.csv   import complete.
# portugal_porto_2021-02-13.csv   import complete.
# spain_mallorca_2021-01-16.csv   import complete.
# canada_quebec-city_2020-06-12.csv   import complete.
# united-states_nashville_2020-06-17.csv   import complete.
# canada_ottawa_2020-05-31.csv   import complete.
# australia_tasmania_2020-09-08.csv   import complete.
# australia_melbourne_2021-01-10.csv   import complete.
# united-states_austin_2020-08-30.csv   import complete.
# italy_puglia_2020-05-19.csv   import complete.
# czech-republic_prague_2021-02-20.csv   import complete.
# united-states_twin-cities-msa_2020-06-09.csv   import complete.
# portugal_lisbon_2020-09-20.csv   import complete.
# united-states_denver_2020-04-30.csv   import complete.
# france_lyon_2020-11-07.csv   import complete.
# united-states_denver_2021-02-26.csv   import complete.
# spain_valencia_2020-09-28.csv   import complete.
# china_hong-kong_2020-11-10.csv   import complete.
# australia_sydney_2020-08-20.csv   import complete.
# united-states_columbus_2020-11-17.csv   import complete.
# united-states_san-diego_2020-12-23.csv   import complete.
# argentina_buenos-aires_2021-03-22.csv   import complete.
# greece_athens_2021-01-27.csv   import complete.
# the-netherlands_amsterdam_2020-06-08.csv   import complete.
# united-states_los-angeles_2020-12-15.csv   import complete.
# spain_mallorca_2021-04-18.csv   import complete.
# italy_bologna_2020-06-15.csv   import complete.
# united-states_dallas_2021-02-21.csv   import complete.
# united-states_san-mateo-county_2020-06-15.csv   import complete.
# spain_menorca_2020-06-30.csv   import complete.
# canada_vancouver_2020-12-16.csv   import complete.
# italy_naples_2020-10-24.csv   import complete.
# australia_barwon-south-west-vic_2020-11-28.csv   import complete.
# spain_madrid_2020-09-13.csv   import complete.
# united-states_pacific-grove_2021-02-27.csv   import complete.
# france_lyon_2020-04-27.csv   import complete.
# france_bordeaux_2020-11-08.csv   import complete.
# latvia_riga_2021-03-29.csv   import complete.
# ireland_dublin_2021-01-13.csv   import complete.
# spain_barcelona_2020-11-06.csv   import complete.
# united-kingdom_bristol_2021-02-23.csv   import complete.
# spain_madrid_2020-07-17.csv   import complete.
# united-states_los-angeles_2021-04-07.csv   import complete.
# australia_northern-rivers_2020-05-31.csv   import complete.
# united-states_oakland_2020-10-25.csv   import complete.
# belgium_ghent_2021-03-20.csv   import complete.
# united-states_hawaii_2020-08-31.csv   import complete.
# united-states_hawaii_2020-06-08.csv   import complete.
# the-netherlands_amsterdam_2020-08-18.csv   import complete.
# france_bordeaux_2020-08-29.csv   import complete.
# thailand_bangkok_2021-03-21.csv   import complete.
# belgium_brussels_2020-06-15.csv   import complete.
# portugal_lisbon_2021-04-16.csv   import complete.
# switzerland_zurich_2020-12-30.csv   import complete.
# united-states_santa-cruz-county_2021-03-30.csv   import complete.
# germany_munich_2021-03-22.csv   import complete.
# italy_rome_2020-04-29.csv   import complete.
# south-africa_cape-town_2021-03-25.csv   import complete.
# taiwan_taipei_2020-12-31.csv   import complete.
# united-states_new-orleans_2021-04-10.csv   import complete.
# chile_santiago_2020-06-21.csv   import complete.
# united-states_los-angeles_2020-07-09.csv   import complete.
# united-states_chicago_2020-05-23.csv   import complete.
# united-kingdom_bristol_2020-06-18.csv   import complete.
# united-states_chicago_2021-03-09.csv   import complete.
# italy_naples_2020-12-20.csv   import complete.
# france_paris_2021-01-10.csv   import complete.
# turkey_istanbul_2020-12-31.csv   import complete.
# spain_malaga_2020-12-30.csv   import complete.
# italy_milan_2020-08-31.csv   import complete.
# united-states_boston_2020-05-12.csv   import complete.
# united-states_twin-cities-msa_2020-11-10.csv   import complete.
# united-states_columbus_2020-10-25.csv   import complete.
# france_lyon_2020-12-18.csv   import complete.
# ireland_dublin_2020-11-06.csv   import complete.
# united-states_rhode-island_2021-03-30.csv   import complete.
# united-states_washington-dc_2020-05-23.csv   import complete.
# united-states_washington-dc_2021-03-09.csv   import complete.
# italy_bologna_2021-01-19.csv   import complete.
# spain_sevilla_2020-05-30.csv   import complete.
# united-states_hawaii_2020-07-07.csv   import complete.
# germany_munich_2020-11-26.csv   import complete.
# china_hong-kong_2020-05-17.csv   import complete.
# united-states_asheville_2020-04-30.csv   import complete.
# ireland_dublin_2020-06-22.csv   import complete.
# latvia_riga_2021-02-26.csv   import complete.
# united-states_austin_2020-05-16.csv   import complete.
# latvia_riga_2020-04-30.csv   import complete.
# sweden_stockholm_2021-03-27.csv   import complete.
# italy_venice_2021-04-09.csv   import complete.
# australia_barwon-south-west-vic_2020-10-26.csv   import complete.
# ireland_dublin_2020-08-27.csv   import complete.
# united-states_nashville_2020-07-25.csv   import complete.
# portugal_porto_2021-04-16.csv   import complete.
# united-states_new-york-city_2020-11-02.csv   import complete.
# argentina_buenos-aires_2020-11-27.csv   import complete.
# australia_sydney_2021-03-04.csv   import complete.
# france_paris_2020-11-05.csv   import complete.
# australia_melbourne_2020-11-05.csv   import complete.
# the-netherlands_amsterdam_2021-04-09.csv   import complete.
# greece_crete_2021-01-30.csv   import complete.
# united-states_denver_2021-03-29.csv   import complete.
# united-states_oakland_2021-02-20.csv   import complete.
# canada_quebec-city_2020-10-13.csv   import complete.
# united-kingdom_edinburgh_2021-01-16.csv   import complete.
# czech-republic_prague_2021-03-13.csv   import complete.
# singapore_singapore_2020-10-26.csv   import complete.
# united-states_asheville_2020-08-31.csv   import complete.
# united-states_austin_2020-09-17.csv   import complete.
# australia_western-australia_2020-12-23.csv   import complete.
# italy_rome_2020-12-17.csv   import complete.
# spain_mallorca_2020-06-25.csv   import complete.
# south-africa_gauteng_2020-12-31.csv   import complete.
# czech-republic_prague_2020-12-21.csv   import complete.
# spain_euskadi_2021-03-30.csv   import complete.
# italy_sicily_2021-03-27.csv   import complete.
# sweden_stockholm_2020-05-30.csv   import complete.
# australia_western-australia_2020-10-26.csv   import complete.
# italy_florence_2021-02-19.csv   import complete.
# brazil_rio-de-janeiro_2020-07-22.csv   import complete.
# portugal_porto_2020-07-25.csv   import complete.
# united-states_salem-or_2021-03-19.csv   import complete.
# united-kingdom_london_2021-03-05.csv   import complete.
# canada_quebec-city_2021-04-11.csv   import complete.
# united-states_columbus_2020-07-28.csv   import complete.
# united-states_hawaii_2020-09-17.csv   import complete.
# united-states_san-mateo-county_2021-01-24.csv   import complete.
# greece_athens_2020-06-16.csv   import complete.
# spain_girona_2020-11-28.csv   import complete.
# spain_barcelona_2021-01-12.csv   import complete.
# canada_quebec-city_2020-12-16.csv   import complete.
# greece_thessaloniki_2020-05-18.csv   import complete.
# canada_montreal_2020-06-15.csv   import complete.
# norway_oslo_2020-11-30.csv   import complete.
# australia_sydney_2020-07-14.csv   import complete.
# portugal_lisbon_2021-02-13.csv   import complete.
# united-states_rhode-island_2020-05-31.csv   import complete.
# chile_santiago_2020-12-24.csv   import complete.
# france_bordeaux_2020-09-19.csv   import complete.
# italy_milan_2020-05-15.csv   import complete.
# belize_belize_2020-10-27.csv   import complete.
# united-states_clark-county-nv_2021-03-12.csv   import complete.
# china_shanghai_2020-10-26.csv   import complete.
# spain_euskadi_2020-05-30.csv   import complete.
# japan_tokyo_2020-10-27.csv   import complete.
# australia_northern-rivers_2020-04-29.csv   import complete.
# italy_venice_2021-03-03.csv   import complete.
# australia_tasmania_2021-02-07.csv   import complete.
# the-netherlands_amsterdam_2020-10-09.csv   import complete.
# united-kingdom_london_2020-07-14.csv   import complete.
# united-states_jersey-city_2020-10-25.csv   import complete.
# taiwan_taipei_2021-02-27.csv   import complete.
# portugal_porto_2021-03-08.csv   import complete.
# united-kingdom_london_2020-09-11.csv   import complete.
# switzerland_zurich_2020-04-30.csv   import complete.
# china_shanghai_2020-12-23.csv   import complete.
# switzerland_geneva_2020-05-28.csv   import complete.
# spain_valencia_2020-11-10.csv   import complete.
# italy_bergamo_2021-01-31.csv   import complete.
# italy_florence_2020-08-31.csv   import complete.
# switzerland_zurich_2021-02-26.csv   import complete.
# switzerland_vaud_2021-02-04.csv   import complete.
# south-africa_gauteng_2021-03-29.csv   import complete.
# spain_malaga_2020-04-30.csv   import complete.
# china_beijing_2020-05-27.csv   import complete.
# australia_northern-rivers_2020-11-08.csv   import complete.
# austria_vienna_2020-09-15.csv   import complete.
# france_bordeaux_2020-05-25.csv   import complete.
# italy_florence_2020-11-10.csv   import complete.
# austria_vienna_2021-01-13.csv   import complete.
# canada_vancouver_2020-06-13.csv   import complete.
# united-states_clark-county-nv_2020-10-24.csv   import complete.
# united-kingdom_bristol_2020-10-25.csv   import complete.
# spain_valencia_2020-08-30.csv   import complete.
# canada_montreal_2021-02-11.csv   import complete.
# united-states_hawaii_2020-12-18.csv   import complete.
# turkey_istanbul_2021-02-26.csv   import complete.
# mexico_mexico-city_2020-11-27.csv   import complete.
# greece_thessaloniki_2020-07-22.csv   import complete.
# united-states_cambridge_2020-11-28.csv   import complete.
# belgium_ghent_2020-11-26.csv   import complete.
# italy_rome_2021-04-13.csv   import complete.
# spain_malaga_2021-02-27.csv   import complete.
# united-states_san-francisco_2020-06-08.csv   import complete.
# australia_northern-rivers_2020-08-28.csv   import complete.
# spain_madrid_2021-02-09.csv   import complete.
# belgium_antwerp_2020-06-22.csv   import complete.
# united-states_los-angeles_2020-06-10.csv   import complete.
# brazil_rio-de-janeiro_2020-05-24.csv   import complete.
# taiwan_taipei_2020-04-30.csv   import complete.
# united-states_washington-dc_2020-09-21.csv   import complete.
# united-states_nashville_2021-01-19.csv   import complete.
# china_hong-kong_2021-03-17.csv   import complete.
# belgium_antwerp_2021-02-25.csv   import complete.
# canada_toronto_2020-07-09.csv   import complete.
# italy_florence_2020-04-30.csv   import complete.
# canada_victoria_2021-03-27.csv   import complete.
# united-states_san-diego_2021-02-21.csv   import complete.
# united-states_dallas_2021-03-11.csv   import complete.
# united-states_salem-or_2020-05-30.csv   import complete.
# united-states_seattle_2020-06-17.csv   import complete.
# united-kingdom_london_2020-05-10.csv   import complete.
# united-states_clark-county-nv_2020-12-21.csv   import complete.
# united-states_austin_2020-12-18.csv   import complete.
# greece_south-aegean_2020-11-10.csv   import complete.
# canada_ottawa_2020-11-08.csv   import complete.
# australia_sydney_2020-09-10.csv   import complete.
# spain_menorca_2020-10-30.csv   import complete.
# spain_malaga_2020-06-30.csv   import complete.
# united-states_hawaii_2020-10-19.csv   import complete.
# switzerland_vaud_2020-08-17.csv   import complete.
# italy_milan_2020-12-20.csv   import complete.
# spain_madrid_2020-11-06.csv   import complete.
# spain_barcelona_2020-09-12.csv   import complete.
# france_bordeaux_2020-07-25.csv   import complete.
# italy_naples_2020-08-31.csv   import complete.
# spain_barcelona_2020-07-17.csv   import complete.
# greece_crete_2021-03-26.csv   import complete.
# south-africa_cape-town_2020-11-27.csv   import complete.
# france_paris_2021-02-08.csv   import complete.
# turkey_istanbul_2020-11-29.csv   import complete.
# south-africa_gauteng_2020-10-27.csv   import complete.
# united-states_los-angeles_2021-02-07.csv   import complete.
# france_paris_2020-08-22.csv   import complete.
# italy_milan_2021-01-17.csv   import complete.
# united-states_boston_2021-02-19.csv   import complete.
# spain_sevilla_2021-01-31.csv   import complete.
# canada_ottawa_2021-02-13.csv   import complete.
# sweden_stockholm_2021-01-30.csv   import complete.
# italy_florence_2020-06-19.csv   import complete.
# united-states_rhode-island_2020-10-29.csv   import complete.
# united-states_san-diego_2020-11-12.csv   import complete.
# united-states_new-york-city_2020-06-08.csv   import complete.
# united-kingdom_greater-manchester_2021-01-24.csv   import complete.
# united-states_pacific-grove_2020-10-30.csv   import complete.
# australia_western-australia_2020-05-14.csv   import complete.
# united-states_austin_2020-10-19.csv   import complete.
# spain_valencia_2020-06-30.csv   import complete.
# italy_naples_2020-04-30.csv   import complete.
# china_beijing_2021-03-21.csv   import complete.
# china_hong-kong_2020-10-25.csv   import complete.
# spain_barcelona_2021-03-05.csv   import complete.
# italy_milan_2020-10-24.csv   import complete.
# spain_menorca_2020-12-30.csv   import complete.
# portugal_lisbon_2020-08-29.csv   import complete.
# united-kingdom_greater-manchester_2020-07-27.csv   import complete.
# united-states_san-mateo-county_2020-12-29.csv   import complete.
# france_lyon_2021-01-14.csv   import complete.
# united-states_clark-county-nv_2020-09-28.csv   import complete.
# australia_barwon-south-west-vic_2020-12-30.csv   import complete.
# portugal_lisbon_2020-11-08.csv   import complete.
# united-states_twin-cities-msa_2020-10-24.csv   import complete.
# united-states_hawaii_2021-03-07.csv   import complete.
# denmark_copenhagen_2020-04-28.csv   import complete.
# united-states_cambridge_2020-06-21.csv   import complete.
# united-states_hawaii_2020-05-11.csv   import complete.
# malta_visualisations_listings.csv.csv   import complete.
# australia_melbourne_2021-02-08.csv   import complete.
# italy_venice_2020-05-11.csv   import complete.
# switzerland_zurich_2020-06-25.csv   import complete.
# france_lyon_2021-04-18.csv   import complete.
# united-states_austin_2021-03-07.csv   import complete.
# australia_northern-rivers_2021-02-13.csv   import complete.
# canada_toronto_2020-09-09.csv   import complete.
# brazil_rio-de-janeiro_2021-01-26.csv   import complete.
# italy_bologna_2020-07-20.csv   import complete.
# united-states_jersey-city_2020-12-24.csv   import complete.
# italy_bologna_2020-09-25.csv   import complete.
# switzerland_zurich_2020-11-29.csv   import complete.
# austria_vienna_2021-03-07.csv   import complete.
# united-kingdom_greater-manchester_2021-03-20.csv   import complete.
# greece_thessaloniki_2021-03-20.csv   import complete.
# united-states_twin-cities-msa_2021-03-13.csv   import complete.
# portugal_lisbon_2020-04-29.csv   import complete.
# belgium_brussels_2021-01-23.csv   import complete.
# united-states_santa-clara-county_2020-06-12.csv   import complete.
# australia_sydney_2021-01-10.csv   import complete.
# canada_montreal_2020-08-28.csv   import complete.
# china_hong-kong_2020-12-22.csv   import complete.
# china_beijing_2021-01-26.csv   import complete.
# switzerland_geneva_2020-10-27.csv   import complete.
# united-states_chicago_2020-11-08.csv   import complete.
# united-kingdom_edinburgh_2020-12-19.csv   import complete.
# united-states_hawaii_2021-01-14.csv   import complete.
# italy_milan_2021-03-11.csv   import complete.
# greece_south-aegean_2020-06-27.csv   import complete.
# france_lyon_2021-03-07.csv   import complete.
# italy_bergamo_2020-05-30.csv   import complete.
# australia_barossa-valley_2020-11-23.csv   import complete.
# belize_belize_2020-12-30.csv   import complete.
# united-states_salem-or_2021-01-24.csv   import complete.
# brazil_rio-de-janeiro_2021-03-21.csv   import complete.
# latvia_riga_2020-06-30.csv   import complete.
# australia_melbourne_2020-08-20.csv   import complete.
# united-states_austin_2021-01-14.csv   import complete.
# chile_santiago_2021-01-29.csv   import complete.
# spain_euskadi_2021-01-31.csv   import complete.
# australia_tasmania_2020-08-17.csv   import complete.
# united-states_chicago_2021-02-17.csv   import complete.
# spain_girona_2021-02-27.csv   import complete.
# greece_south-aegean_2021-02-20.csv   import complete.
# greece_thessaloniki_2021-01-27.csv   import complete.
# spain_barcelona_2020-05-11.csv   import complete.
# france_lyon_2020-10-24.csv   import complete.
# the-netherlands_amsterdam_2021-03-04.csv   import complete.
# belgium_antwerp_2020-11-28.csv   import complete.
# united-states_broward-county_2020-10-25.csv   import complete.
# canada_toronto_2020-12-12.csv   import complete.
# chile_santiago_2020-10-26.csv   import complete.
# united-states_rhode-island_2021-01-31.csv   import complete.
# united-states_san-francisco_2020-11-02.csv   import complete.
# belize_belize_2020-05-29.csv   import complete.
# spain_sevilla_2020-10-29.csv   import complete.
# italy_sicily_2021-01-27.csv   import complete.
# united-states_asheville_2020-06-25.csv   import complete.
# italy_venice_2020-07-17.csv   import complete.
# spain_girona_2020-04-30.csv   import complete.
# united-kingdom_edinburgh_2020-10-21.csv   import complete.
# united-kingdom_london_2021-01-11.csv   import complete.
# canada_victoria_2021-01-30.csv   import complete.
# united-states_san-mateo-county_2021-03-18.csv   import complete.
# germany_berlin_2020-06-13.csv   import complete.
# spain_madrid_2020-08-25.csv   import complete.
# united-states_cambridge_2021-02-25.csv   import complete.
# united-states_twin-cities-msa_2020-12-22.csv   import complete.
# canada_new-brunswick_2020-11-30.csv   import complete.
# portugal_porto_2020-09-19.csv   import complete.
# italy_rome_2020-10-17.csv   import complete.
# united-states_nashville_2020-05-18.csv   import complete.
# czech-republic_prague_2020-10-09.csv   import complete.
# united-states_oakland_2020-11-12.csv   import complete.
# united-states_santa-cruz-county_2020-11-30.csv   import complete.
# united-states_boston_2020-08-31.csv   import complete.
# spain_valencia_2021-02-20.csv   import complete.
# united-states_boston_2020-11-10.csv   import complete.
# united-states_twin-cities-msa_2020-05-12.csv   import complete.
#                   id                                               name  \
# 0            41339.0                       Porto city flat near the sea
# 1            42462.0                  Large Penthouse in Vila Nova Gaia
# 2            55111.0  Fontielas Houses |Floor1 in House with shared ...
# 3            73828.0  Fontielas Houses |Floor0 in House with shared ...
# 4            86388.0                    A Formosa - a nest made for two
# ...              ...                                                ...
# 12176730  43348647.0                                   Recámara Privada
# 12176731  43389505.0                   Private Room in Private Basement
# 12176732  43390452.0                                    The Grace Space
# 12176733  43405075.0  Prior Lake Cottage home on prime Bay of the Lake!
# 12176734  43406070.0  Downtown Private Master Bedroom + many amenities!
#
#               host_id      host_name neighbourhood_group  \
# 0            180050.0          Paula               PORTO
# 1            185492.0       Gabriela   VILA NOVA DE GAIA
# 2            259711.0  Isabel E João             PAREDES
# 3            259711.0  Isabel E João             PAREDES
# 4            185209.0           João               PORTO
# ...               ...            ...                 ...
# 12176730  175669735.0          Josue                 NaN
# 12176731  129740000.0             Aj                 NaN
# 12176732   33383865.0         Andrea                 NaN
# 12176733  111948008.0            Ann                 NaN
# 12176734   77360805.0           Drew                 NaN
#
#                                               neighbourhood  latitude  \
# 0                              Lordelo do Ouro e Massarelos  41.15010
# 1                               Mafamude e Vilar do Paraíso  41.10739
# 2                                                      Cete  41.17481
# 3                                                      Cete  41.17449
# 4         Cedofeita, Ildefonso, Sé, Miragaia, Nicolau, V...  41.14918
# ...                                                     ...       ...
# 12176730                                           Hennepin  45.01486
# 12176731                                           Hennepin  45.00723
# 12176732                                             Ramsey  45.08582
# 12176733                                              Scott  44.74567
# 12176734                                           Hennepin  44.97210
#
#           longitude        room_type  price  minimum_nights  \
# 0          -8.66035  Entire home/apt   75.0             5.0
# 1          -8.59430  Entire home/apt   73.0            30.0
# 2          -8.35362  Entire home/apt   66.0             3.0
# 3          -8.35426  Entire home/apt   66.0             3.0
# 4          -8.60922     Private room   20.0             2.0
# ...             ...              ...    ...             ...
# 12176730  -93.30547     Private room   40.0             1.0
# 12176731  -93.29911     Private room   50.0             2.0
# 12176732  -93.02009  Entire home/apt  159.0             5.0
# 12176733  -93.39000  Entire home/apt  300.0             5.0
# 12176734  -93.27319     Private room   62.0            20.0
#
#           number_of_reviews last_review  reviews_per_month  \
# 0                      17.0  2018-09-28               0.19
# 1                      39.0  2018-10-14               0.41
# 2                      14.0  2019-09-07               0.22
# 3                       8.0  2019-07-22               0.12
# 4                     136.0  2020-09-23               1.18
# ...                     ...         ...                ...
# 12176730                3.0  2020-05-11               3.00
# 12176731                0.0         NaN                NaN
# 12176732                0.0         NaN                NaN
# 12176733                0.0         NaN                NaN
# 12176734                0.0         NaN                NaN
#
#           calculated_host_listings_count  availability_365  \
# 0                                    1.0               0.0
# 1                                    3.0               1.0
# 2                                    3.0               0.0
# 3                                    3.0               0.0
# 4                                    6.0             231.0
# ...                                  ...               ...
# 12176730                             1.0             362.0
# 12176731                             1.0              86.0
# 12176732                             2.0              87.0
# 12176733                             1.0             356.0
# 12176734                             1.0             113.0
#
#                                               filename <html>  \
# 0                        portugal_porto_2020-10-21.csv    NaN
# 1                        portugal_porto_2020-10-21.csv    NaN
# 2                        portugal_porto_2020-10-21.csv    NaN
# 3                        portugal_porto_2020-10-21.csv    NaN
# 4                        portugal_porto_2020-10-21.csv    NaN
# ...                                                ...    ...
# 12176730  united-states_twin-cities-msa_2020-05-12.csv    NaN
# 12176731  united-states_twin-cities-msa_2020-05-12.csv    NaN
# 12176732  united-states_twin-cities-msa_2020-05-12.csv    NaN
# 12176733  united-states_twin-cities-msa_2020-05-12.csv    NaN
# 12176734  united-states_twin-cities-msa_2020-05-12.csv    NaN
#
#           number_of_reviews_ltm
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
# ...                         ...
# 12176730                    NaN
# 12176731                    NaN
# 12176732                    NaN
# 12176733                    NaN
# 12176734                    NaN
#
# [12176735 rows x 19 columns]

# %%
print('Before dropping rows the shape of the dataframe is ', merged_df.shape)

# Dropping Columns that may not be used in model or that have high NaN values
merged_df.drop(labels=['id', 'name', 'host_id', 'host_name', 'number_of_reviews_ltm', 'neighbourhood_group', 'reviews_per_month', 'last_review', '<html>'], axis=1, inplace=True)

# Drop Duplicate Values and only retain the later one
merged_df.drop_duplicates(subset=['neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
       'minimum_nights', 'number_of_reviews', 'calculated_host_listings_count',
       'availability_365', 'filename'], keep='last', inplace=True)

# Dropping na rows, only 71 rows
merged_df.dropna(inplace=True)

# Dropping rows where price was too less (less than 10 in local currency) and too high (more than 1 Million in local currency)
merged_df.drop(merged_df[merged_df['price'] < 10].index, inplace=True)
merged_df.drop(merged_df[merged_df['price'] > 1000000].index, inplace=True)

# Dropping rows where minimum_nights is unjustifiable like more than 1500 nights
merged_df.drop(merged_df[merged_df['minimum_nights'] > 1500].index, inplace=True)
# check updated shape
print('After dropping rows the shape of the dataframe is ', merged_df.shape)
# Out:
# Before dropping rows the shape of the dataframe is  (12176735, 19)
# After dropping rows the shape of the dataframe is  (12155794, 10)

# %%
# Display merged data after Dropping columns
merged_df.head(5)
# Out:
#                                        neighbourhood  latitude  longitude  \
# 0                       Lordelo do Ouro e Massarelos  41.15010   -8.66035
# 1                        Mafamude e Vilar do Paraíso  41.10739   -8.59430
# 2                                               Cete  41.17481   -8.35362
# 3                                               Cete  41.17449   -8.35426
# 4  Cedofeita, Ildefonso, Sé, Miragaia, Nicolau, V...  41.14918   -8.60922
#
#          room_type  price  minimum_nights  number_of_reviews  \
# 0  Entire home/apt   75.0             5.0               17.0
# 1  Entire home/apt   73.0            30.0               39.0
# 2  Entire home/apt   66.0             3.0               14.0
# 3  Entire home/apt   66.0             3.0                8.0
# 4     Private room   20.0             2.0              136.0
#
#    calculated_host_listings_count  availability_365  \
# 0                             1.0               0.0
# 1                             3.0               1.0
# 2                             3.0               0.0
# 3                             3.0               0.0
# 4                             6.0             231.0
#
#                         filename
# 0  portugal_porto_2020-10-21.csv
# 1  portugal_porto_2020-10-21.csv
# 2  portugal_porto_2020-10-21.csv
# 3  portugal_porto_2020-10-21.csv
# 4  portugal_porto_2020-10-21.csv

# %%
# Export to the CSV file for future use
merged_df.to_csv('merged_df.csv', index=False)

# %%
merged_df1 = merged_df.drop(labels='filename', axis=1)
# Check if the data is having no null values
merged_df1.isnull().sum()
# Out:
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# calculated_host_listings_count    0
# availability_365                  0
# dtype: int64

# %%
# Display the summary of statistics
merged_df1.describe(include='all')
# Out:
#            neighbourhood      latitude     longitude        room_type  \
# count           12155794  1.215579e+07  1.215579e+07         12155794
# unique              7044           NaN           NaN                4
# top     I Centro Storico           NaN           NaN  Entire home/apt
# freq              151180           NaN           NaN          8419984
# mean                 NaN  3.002005e+01  5.946818e-01              NaN
# std                  NaN  2.762039e+01  7.490316e+01              NaN
# min                  NaN -4.690624e+01 -1.762681e+02              NaN
# 25%                  NaN  3.121871e+01 -5.840575e+01              NaN
# 50%                  NaN  4.041108e+01  2.565030e+00              NaN
# 75%                  NaN  4.554059e+01  1.829750e+01              NaN
# max                  NaN  6.003894e+01  1.784805e+02              NaN
#
#                price  minimum_nights  number_of_reviews  \
# count   1.215579e+07    1.215579e+07       1.215579e+07
# unique           NaN             NaN                NaN
# top              NaN             NaN                NaN
# freq             NaN             NaN                NaN
# mean    9.141725e+02    6.552030e+00       2.474396e+01
# std     9.022593e+03    2.381185e+01       5.241428e+01
# min     1.000000e+01    1.000000e+00       0.000000e+00
# 25%     6.000000e+01    1.000000e+00       0.000000e+00
# 50%     1.080000e+02    2.000000e+00       4.000000e+00
# 75%     2.510000e+02    4.000000e+00       2.300000e+01
# max     1.000000e+06    1.360000e+03       1.010000e+03
#
#         calculated_host_listings_count  availability_365
# count                     1.215579e+07      1.215579e+07
# unique                             NaN               NaN
# top                                NaN               NaN
# freq                               NaN               NaN
# mean                      1.378731e+01      1.722744e+02
# std                       5.168367e+01      1.460285e+02
# min                       1.000000e+00      0.000000e+00
# 25%                       1.000000e+00      1.000000e+00
# 50%                       2.000000e+00      1.680000e+02
# 75%                       6.000000e+00      3.400000e+02
# max                       9.370000e+02      3.660000e+02

# %%
# Export to html using pandas profiling to see the data statistics
profile = ProfileReport(merged_df1, minimal=True)

profile.to_file('Pandas_Profiling_Report.html')
# Out:
# Summarize dataset:   0%|          | 0/18 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
